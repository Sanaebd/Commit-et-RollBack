# %%
import pyodbc 
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=.;'
                      'Database=WideWorldImporters;'
                      'Trusted_Connection=yes;')
cursor = conn.cursor()
cursor.execute("select CustomerID, CustomerName from WideWorldImporters.Sales.Customers")

for row in cursor:
    print(row)
# Out:
# (1, 'Tailspin Toys (Head Office)')
# (2, 'Tailspin Toys (Sylvanite, MT)')
# (3, 'Tailspin Toys (Peeples Valley, AZ)')
# (4, 'Tailspin Toys (Medicine Lodge, KS)')
# (5, 'Tailspin Toys (Gasport, NY)')
# (6, 'Tailspin Toys (Jessie, ND)')
# (7, 'Tailspin Toys (Frankewing, TN)')
# (8, 'Tailspin Toys (Bow Mar, CO)')
# (9, 'Tailspin Toys (Netcong, NJ)')
# (10, 'Tailspin Toys (Wimbledon, ND)')
# (11, 'Tailspin Toys (Devault, PA)')
# (12, 'Tailspin Toys (Biscay, MN)')
# (13, 'Tailspin Toys (Stonefort, IL)')
# (14, 'Tailspin Toys (Long Meadow, MD)')
# (15, 'Tailspin Toys (Batson, TX)')
# (16, 'Tailspin Toys (Coney Island, MO)')
# (17, 'Tailspin Toys (East Fultonham, OH)')
# (18, 'Tailspin Toys (Goffstown, NH)')
# (19, 'Tailspin Toys (Lemeta, AK)')
# (20, 'Tailspin Toys (College Place, WA)')
# (21, 'Tailspin Toys (Tresckow, PA)')
# (22, 'Tailspin Toys (Ward Ridge, FL)')
# (23, 'Tailspin Toys (Ikatan, AK)')
# (24, 'Tailspin Toys (Dundarrach, NC)')
# (25, 'Tailspin Toys (Avenal, CA)')
# (26, 'Tailspin Toys (Hedrick, IA)')
# (27, 'Tailspin Toys (Bowlus, MN)')
# (28, 'Tailspin Toys (North Ridge, NY)')
# (29, 'Tailspin Toys (Eulaton, AL)')
# (30, 'Tailspin Toys (Koontzville, WA)')
# (31, 'Tailspin Toys (Lake Stevens, WA)')
# (32, 'Tailspin Toys (Maypearl, TX)')
# (33, 'Tailspin Toys (Boyden Arbor, SC)')
# (34, 'Tailspin Toys (Dallardsville, TX)')
# (35, 'Tailspin Toys (Slanesville, WV)')
# (36, 'Tailspin Toys (Ekron, KY)')
# (37, 'Tailspin Toys (Kerby, OR)')
# (38, 'Tailspin Toys (Airport Drive, MO)')
# (39, 'Tailspin Toys (Diablock, KY)')
# (40, 'Tailspin Toys (Impact, TX)')
# (41, 'Tailspin Toys (Olivette, MO)')
# (42, 'Tailspin Toys (Arietta, NY)')
# (43, 'Tailspin Toys (Upper Preston, WA)')
# (44, 'Tailspin Toys (Amanda Park, WA)')
# (45, 'Tailspin Toys (Severna Park, MD)')
# (46, 'Tailspin Toys (Jemison, AL)')
# (47, 'Tailspin Toys (Lake Hughes, CA)')
# (48, 'Tailspin Toys (Trentwood, WA)')
# (49, 'Tailspin Toys (Muir, MI)')
# (50, 'Tailspin Toys (Hambleton, WV)')
# (51, 'Tailspin Toys (Imlaystown, NJ)')
# (52, 'Tailspin Toys (Idria, CA)')
# (53, 'Tailspin Toys (Nanafalia, AL)')
# (54, 'Tailspin Toys (Railroad, PA)')
# (55, 'Tailspin Toys (Gum Branch, GA)')
# (56, 'Tailspin Toys (Royal City, WA)')
# (57, 'Tailspin Toys (Lakemore, OH)')
# (58, 'Tailspin Toys (Mappsburg, VA)')
# (59, 'Tailspin Toys (Edgartown, MA)')
# (60, 'Tailspin Toys (East Dailey, WV)')
# (61, 'Tailspin Toys (Fairfield Glade, TN)')
# (62, 'Tailspin Toys (Great Neck Estates, NY)')
# (63, 'Tailspin Toys (Stallion Springs, CA)')
# (64, 'Tailspin Toys (Hodgdon, ME)')
# (65, 'Tailspin Toys (North Cowden, TX)')
# (66, 'Tailspin Toys (Madaket, MA)')
# (67, 'Tailspin Toys (Sentinel Butte, ND)')
# (68, 'Tailspin Toys (Gardere, LA)')
# (69, 'Tailspin Toys (Lytle Creek, CA)')
# (70, 'Tailspin Toys (New Baden, IL)')
# (71, 'Tailspin Toys (Good Hart, MI)')
# (72, 'Tailspin Toys (Cortaro, AZ)')
# (73, 'Tailspin Toys (Cokato, MN)')
# (74, 'Tailspin Toys (Indios, PR)')
# (75, 'Tailspin Toys (Windsor Locks, CT)')
# (76, 'Tailspin Toys (Yewed, OK)')
# (77, 'Tailspin Toys (Hahira, GA)')
# (78, 'Tailspin Toys (Sekiu, WA)')
# (79, 'Tailspin Toys (Page City, KS)')
# (80, 'Tailspin Toys (Valdese, NC)')
# (81, 'Tailspin Toys (Big Moose, NY)')
# (82, 'Tailspin Toys (La Cueva, NM)')
# (83, 'Tailspin Toys (Absecon, NJ)')
# (84, 'Tailspin Toys (Aceitunas, PR)')
# (85, 'Tailspin Toys (Andrix, CO)')
# (86, 'Tailspin Toys (New Lexington, OH)')
# (87, 'Tailspin Toys (Sauquoit, NY)')
# (88, 'Tailspin Toys (Dracut, MA)')
# (89, 'Tailspin Toys (Victory Gardens, NJ)')
# (90, 'Tailspin Toys (Tolna, ND)')
# (91, 'Tailspin Toys (Alstead, NH)')
# (92, 'Tailspin Toys (Sans Souci, SC)')
# (93, 'Tailspin Toys (Clewiston, FL)')
# (94, 'Tailspin Toys (Cheyenne Wells, CO)')
# (95, 'Tailspin Toys (Lavon, TX)')
# (96, 'Tailspin Toys (South La Paloma, TX)')
# (97, 'Tailspin Toys (Manchester Center, VT)')
# (98, 'Tailspin Toys (El Centro, CA)')
# (99, 'Tailspin Toys (Guin, AL)')
# (100, 'Tailspin Toys (Tunnelhill, PA)')
# (101, 'Tailspin Toys (Cundiyo, NM)')
# (102, 'Tailspin Toys (Fieldbrook, CA)')
# (103, 'Tailspin Toys (Kalvesta, KS)')
# (104, 'Tailspin Toys (Wallagrass, ME)')
# (105, 'Tailspin Toys (Tomnolen, MS)')
# (106, 'Tailspin Toys (Tumacacori, AZ)')
# (107, 'Tailspin Toys (Glen Avon, CA)')
# (108, 'Tailspin Toys (Bernie, MO)')
# (109, 'Tailspin Toys (South Laguna, CA)')
# (110, 'Tailspin Toys (North Crows Nest, IN)')
# (111, 'Tailspin Toys (Oriole Beach, FL)')
# (112, 'Tailspin Toys (Sallyards, KS)')
# (113, 'Tailspin Toys (Dahlia, NM)')
# (114, 'Tailspin Toys (Cherry Grove Beach, SC)')
# (115, 'Tailspin Toys (Bethania, NC)')
# (116, 'Tailspin Toys (Rafael Capó, PR)')
# (117, 'Tailspin Toys (Scofield, UT)')
# (118, 'Tailspin Toys (Vassalboro, ME)')
# (119, 'Tailspin Toys (Statenville, GA)')
# (120, 'Tailspin Toys (Bratenahl, OH)')
# (121, 'Tailspin Toys (Elrosa, MN)')
# (122, 'Tailspin Toys (McClave, CO)')
# (123, 'Tailspin Toys (Roe Park, NY)')
# (124, 'Tailspin Toys (Hanoverton, OH)')
# (125, 'Tailspin Toys (Annamoriah, WV)')
# (126, 'Tailspin Toys (Francis Mills, NJ)')
# (127, 'Tailspin Toys (Point Roberts, WA)')
# (128, 'Tailspin Toys (East Portal, CO)')
# (129, 'Tailspin Toys (Mineral Hills, MI)')
# (130, 'Tailspin Toys (Maple Shade, NJ)')
# (131, 'Tailspin Toys (Kwethluk, AK)')
# (132, 'Tailspin Toys (Minidoka, ID)')
# (133, 'Tailspin Toys (Lake Erie Beach, NY)')
# (134, 'Tailspin Toys (Tavares, FL)')
# (135, 'Tailspin Toys (Terre du Lac, MO)')
# (136, 'Tailspin Toys (Mount Montgomery, NV)')
# (137, 'Tailspin Toys (Carbonville, UT)')
# (138, 'Tailspin Toys (Navassa, NC)')
# (139, 'Tailspin Toys (Hardeeville, SC)')
# (140, 'Tailspin Toys (Furley, KS)')
# (141, 'Tailspin Toys (Arrow Rock, MO)')
# (142, 'Tailspin Toys (King Cove, AK)')
# (143, 'Tailspin Toys (Ashtabula, OH)')
# (144, 'Tailspin Toys (Larose, LA)')
# (145, 'Tailspin Toys (Manahawkin, NJ)')
# (146, 'Tailspin Toys (Belgreen, AL)')
# (147, 'Tailspin Toys (Fishtail, MT)')
# (148, 'Tailspin Toys (Baraboo, WI)')
# (149, 'Tailspin Toys (Inguadona, MN)')
# (150, 'Tailspin Toys (Corfu, NY)')
# (151, 'Tailspin Toys (Antares, AZ)')
# (152, 'Tailspin Toys (Sun River, MT)')
# (153, 'Tailspin Toys (Marcell, MN)')
# (154, 'Tailspin Toys (Eden Valley, MN)')
# (155, 'Tailspin Toys (Arbor Vitae, WI)')
# (156, 'Tailspin Toys (Hollywood Park, TX)')
# (157, 'Tailspin Toys (Saks, AL)')
# (158, 'Tailspin Toys (Donner, LA)')
# (159, 'Tailspin Toys (Saint Louis Park, MN)')
# (160, 'Tailspin Toys (Crary, ND)')
# (161, 'Tailspin Toys (Aspen Park, CO)')
# (162, 'Tailspin Toys (Glen Park, NY)')
# (163, 'Tailspin Toys (Panaca, NV)')
# (164, 'Tailspin Toys (Rothsville, PA)')
# (165, 'Tailspin Toys (Topstone, CT)')
# (166, 'Tailspin Toys (McCamey, TX)')
# (167, 'Tailspin Toys (Rockwall, TX)')
# (168, 'Tailspin Toys (Seagraves, TX)')
# (169, 'Tailspin Toys (Sinclair, WY)')
# (170, 'Tailspin Toys (Eastchester, NY)')
# (171, 'Tailspin Toys (Ortley Beach, NJ)')
# (172, 'Tailspin Toys (Madrone, NM)')
# (173, 'Tailspin Toys (Wappingers Falls, NY)')
# (174, 'Tailspin Toys (Astor Park, FL)')
# (175, 'Tailspin Toys (San Acacia, NM)')
# (176, 'Tailspin Toys (Malott, WA)')
# (177, 'Tailspin Toys (Orrtanna, PA)')
# (178, 'Tailspin Toys (Armstrong Creek, WI)')
# (179, 'Tailspin Toys (Hiteman, IA)')
# (180, 'Tailspin Toys (Caselton, NV)')
# (181, 'Tailspin Toys (Heilwood, PA)')
# (182, 'Tailspin Toys (Hayes Center, NE)')
# (183, 'Tailspin Toys (Tierra Verde, FL)')
# (184, 'Tailspin Toys (South Euclid, OH)')
# (185, 'Tailspin Toys (Vidrine, LA)')
# (186, 'Tailspin Toys (Placer, OR)')
# (187, 'Tailspin Toys (Brown City, MI)')
# (188, 'Tailspin Toys (Premont, TX)')
# (189, 'Tailspin Toys (Wilkes-Barre, PA)')
# (190, 'Tailspin Toys (Teutopolis, IL)')
# (191, 'Tailspin Toys (Orchard Hill, GA)')
# (192, 'Tailspin Toys (Optimo, NM)')
# (193, 'Tailspin Toys (Knifley, KY)')
# (194, 'Tailspin Toys (Naples Park, FL)')
# (195, 'Tailspin Toys (Lesslie, SC)')
# (196, 'Tailspin Toys (Howells, NE)')
# (197, 'Tailspin Toys (Magalia, CA)')
# (198, 'Tailspin Toys (Buell, MO)')
# (199, 'Tailspin Toys (Antonito, CO)')
# (200, 'Tailspin Toys (Tooele, UT)')
# (201, 'Tailspin Toys (Skyway, WA)')
# (401, 'Wingtip Toys (Head Office)')
# (402, 'Wingtip Toys (Black Lick, PA)')
# (403, 'Wingtip Toys (Queen Valley, AZ)')
# (404, 'Wingtip Toys (Penns Creek, PA)')
# (405, 'Wingtip Toys (Bourbonnais, IL)')
# (406, 'Wingtip Toys (Tuscaloosa, AL)')
# (407, 'Wingtip Toys (Mooringsport, LA)')
# (408, 'Wingtip Toys (Rockwall, TX)')
# (409, 'Wingtip Toys (Orick, CA)')
# (410, 'Wingtip Toys (Bernstein, TX)')
# (411, 'Wingtip Toys (Edmund, WI)')
# (412, 'Wingtip Toys (Bozeman Hot Springs, MT)')
# (413, 'Wingtip Toys (Truscott, TX)')
# (414, 'Wingtip Toys (Rose Tree, PA)')
# (415, 'Wingtip Toys (Leathersville, GA)')
# (416, 'Wingtip Toys (Necedah, WI)')
# (417, 'Wingtip Toys (Chetek, WI)')
# (418, 'Wingtip Toys (Yaak, MT)')
# (419, 'Wingtip Toys (Compass Lake, FL)')
# (420, 'Wingtip Toys (Herlong, CA)')
# (421, 'Wingtip Toys (Highland Home, AL)')
# (422, 'Wingtip Toys (Naches, WA)')
# (423, 'Wingtip Toys (Baldwin City, KS)')
# (424, 'Wingtip Toys (Heartwell, NE)')
# (425, 'Wingtip Toys (Bethel Acres, OK)')
# (426, 'Wingtip Toys (Willow Valley, AZ)')
# (427, 'Wingtip Toys (Athol Springs, NY)')
# (428, 'Wingtip Toys (Paw Paw Lake, MI)')
# (429, 'Wingtip Toys (Lilbourn, MO)')
# (430, 'Wingtip Toys (Lost River, ID)')
# (431, 'Wingtip Toys (Rosa Sánchez, PR)')
# (432, 'Wingtip Toys (Vamo, FL)')
# (433, 'Wingtip Toys (Balko, OK)')
# (434, 'Wingtip Toys (Lime Lake, NY)')
# (435, 'Wingtip Toys (Teutopolis, IL)')
# (436, 'Wingtip Toys (Gargatha, VA)')
# (437, 'Wingtip Toys (Cadogan, PA)')
# (438, 'Wingtip Toys (Lucasville, OH)')
# (439, 'Wingtip Toys (Cylon, WI)')
# (440, 'Wingtip Toys (Asher, OK)')
# (441, 'Wingtip Toys (Keosauqua, IA)')
# (442, 'Wingtip Toys (Homer City, PA)')
# (443, 'Wingtip Toys (Berville, MI)')
# (444, 'Wingtip Toys (Tea, SD)')
# (445, 'Wingtip Toys (Dacono, CO)')
# (446, 'Wingtip Toys (Saint Landry, LA)')
# (447, 'Wingtip Toys (Coin, IA)')
# (448, 'Wingtip Toys (Salt Wells, NV)')
# (449, 'Wingtip Toys (Delray, WV)')
# (450, 'Wingtip Toys (Mount Summit, IN)')
# (451, 'Wingtip Toys (Smoot, WY)')
# (452, 'Wingtip Toys (Lake Davis, CA)')
# (453, 'Wingtip Toys (Stanardsville, VA)')
# (454, 'Wingtip Toys (Corcovado, PR)')
# (455, 'Wingtip Toys (Taft Heights, CA)')
# (456, 'Wingtip Toys (West Hempstead, NY)')
# (457, 'Wingtip Toys (Portales, NM)')
# (458, 'Wingtip Toys (Coker, AL)')
# (459, 'Wingtip Toys (Haydenville, OH)')
# (460, 'Wingtip Toys (Mayhill, NM)')
# (461, 'Wingtip Toys (Vair, TX)')
# (462, 'Wingtip Toys (Crossroads, NM)')
# (463, 'Wingtip Toys (Cowlington, OK)')
# (464, 'Wingtip Toys (Glen Ullin, ND)')
# (465, 'Wingtip Toys (Oologah, OK)')
# (466, 'Wingtip Toys (Lytle, TX)')
# (467, 'Wingtip Toys (Mahaffey, PA)')
# (468, 'Wingtip Toys (Sunburg, MN)')
# (469, 'Wingtip Toys (Johnetta, KY)')
# (470, 'Wingtip Toys (Universal City, TX)')
# (471, 'Wingtip Toys (Ridgemark, CA)')
# (472, 'Wingtip Toys (San Jacinto, CA)')
# (473, 'Wingtip Toys (Floriston, CA)')
# (474, 'Wingtip Toys (Bokeelia, FL)')
# (475, 'Wingtip Toys (Cale, AR)')
# (476, 'Wingtip Toys (Karthaus, PA)')
# (477, 'Wingtip Toys (Glancy, MS)')
# (478, 'Wingtip Toys (Stoneboro, PA)')
# (479, 'Wingtip Toys (Mier, IN)')
# (480, 'Wingtip Toys (Wapinitia, OR)')
# (481, 'Wingtip Toys (White Church, MO)')
# (482, 'Wingtip Toys (Caton, NY)')
# (483, 'Wingtip Toys (Plum Branch, SC)')
# (484, 'Wingtip Toys (Mauldin, SC)')
# (485, 'Wingtip Toys (Bonner Springs, KS)')
# (486, 'Wingtip Toys (Lowellville, OH)')
# (487, 'Wingtip Toys (Elverson, PA)')
# (488, 'Wingtip Toys (Isabela, PR)')
# (489, 'Wingtip Toys (Sayner, WI)')
# (490, 'Wingtip Toys (Beals, ME)')
# (491, 'Wingtip Toys (Morton Grove, IL)')
# (492, 'Wingtip Toys (Birds, IL)')
# (493, 'Wingtip Toys (Federalsburg, MD)')
# (494, 'Wingtip Toys (Pikeview, CO)')
# (495, 'Wingtip Toys (Boalsburg, PA)')
# (496, 'Wingtip Toys (Port Hueneme, CA)')
# (497, 'Wingtip Toys (Verdery, SC)')
# (498, 'Wingtip Toys (Obetz, OH)')
# (499, 'Wingtip Toys (East Fultonham, OH)')
# (500, 'Wingtip Toys (Obion, TN)')
# (501, 'Wingtip Toys (Cavendish, VT)')
# (502, 'Wingtip Toys (Miesville, MN)')
# (503, 'Wingtip Toys (Valhalla, NC)')
# (504, 'Wingtip Toys (Cape Neddick, ME)')
# (505, 'Wingtip Toys (Silver Plume, CO)')
# (506, 'Wingtip Toys (North Beach Haven, NJ)')
# (507, 'Wingtip Toys (Downingtown, PA)')
# (508, 'Wingtip Toys (Branson West, MO)')
# (509, 'Wingtip Toys (Bergen Park, CO)')
# (510, 'Wingtip Toys (Grabill, IN)')
# (511, 'Wingtip Toys (North Manitou, MI)')
# (512, 'Wingtip Toys (Philip, SD)')
# (513, 'Wingtip Toys (Straughn, IN)')
# (514, 'Wingtip Toys (Gilford, NH)')
# (515, 'Wingtip Toys (Del Valle, TX)')
# (516, 'Wingtip Toys (Harkers Island, NC)')
# (517, 'Wingtip Toys (Licking, MO)')
# (518, 'Wingtip Toys (Raton, NM)')
# (519, 'Wingtip Toys (Boynton, OK)')
# (520, 'Wingtip Toys (Frenchburg, KY)')
# (521, 'Wingtip Toys (Robertsdale, AL)')
# (522, 'Wingtip Toys (Dickerson, MD)')
# (523, 'Wingtip Toys (Bruceton Mills, WV)')
# (524, 'Wingtip Toys (Cloquet, MN)')
# (525, 'Wingtip Toys (Claycomo, MO)')
# (526, 'Wingtip Toys (Beekmantown, NY)')
# (527, 'Wingtip Toys (Islip Terrace, NY)')
# (528, 'Wingtip Toys (Rich Creek, VA)')
# (529, 'Wingtip Toys (Griswoldville, GA)')
# (530, 'Wingtip Toys (East Mountain, TX)')
# (531, 'Wingtip Toys (Omer, MI)')
# (532, 'Wingtip Toys (Waycross, GA)')
# (533, 'Wingtip Toys (Nichols Hills, OK)')
# (534, 'Wingtip Toys (Plaquemine, LA)')
# (535, 'Wingtip Toys (Triadelphia, WV)')
# (536, 'Wingtip Toys (Ferney, SD)')
# (537, 'Wingtip Toys (Akhiok, AK)')
# (538, 'Wingtip Toys (Deeson, MS)')
# (539, 'Wingtip Toys (Nuangola, PA)')
# (540, 'Wingtip Toys (Weld, ME)')
# (541, 'Wingtip Toys (Mickleton, NJ)')
# (542, 'Wingtip Toys (Schererville, IN)')
# (543, 'Wingtip Toys (Lexington Heights, MI)')
# (544, 'Wingtip Toys (Broomtown, AL)')
# (545, 'Wingtip Toys (Jamison, IA)')
# (546, 'Wingtip Toys (Key Biscayne, FL)')
# (547, 'Wingtip Toys (Chaseley, ND)')
# (548, 'Wingtip Toys (Indian Creek, IL)')
# (549, 'Wingtip Toys (Lake Ronkonkoma, NY)')
# (550, 'Wingtip Toys (Morrison Bluff, AR)')
# (551, 'Wingtip Toys (Huntingburg, IN)')
# (552, 'Wingtip Toys (Shay, PA)')
# (553, 'Wingtip Toys (Helotes, TX)')
# (554, 'Wingtip Toys (Hollandsburg, IN)')
# (555, 'Wingtip Toys (Liberty Grove, MD)')
# (556, 'Wingtip Toys (Morita, TX)')
# (557, 'Wingtip Toys (New Laguna, NM)')
# (558, 'Wingtip Toys (Bourneville, OH)')
# (559, 'Wingtip Toys (Mendoza, TX)')
# (560, 'Wingtip Toys (Palmas del Mar, PR)')
# (561, 'Wingtip Toys (Marion Junction, AL)')
# (562, 'Wingtip Toys (Ware Shoals, SC)')
# (563, 'Wingtip Toys (Lostine, OR)')
# (564, 'Wingtip Toys (Tilleda, WI)')
# (565, 'Wingtip Toys (Wapiti, WY)')
# (566, 'Wingtip Toys (Amado, AZ)')
# (567, 'Wingtip Toys (Jeromesville, OH)')
# (568, 'Wingtip Toys (Ovilla, TX)')
# (569, 'Wingtip Toys (West Frostproof, FL)')
# (570, 'Wingtip Toys (Flomaton, AL)')
# (571, 'Wingtip Toys (Pawlet, VT)')
# (572, 'Wingtip Toys (Trout Run, PA)')
# (573, 'Wingtip Toys (Marin City, CA)')
# (574, 'Wingtip Toys (Molalla, OR)')
# (575, 'Wingtip Toys (Trumansburg, NY)')
# (576, 'Wingtip Toys (Goodings Grove, IL)')
# (577, 'Wingtip Toys (Cherryplain, NY)')
# (578, 'Wingtip Toys (Bell Acres, PA)')
# (579, 'Wingtip Toys (Connoquenessing, PA)')
# (580, 'Wingtip Toys (Sarversville, PA)')
# (581, 'Wingtip Toys (Munich, ND)')
# (582, 'Wingtip Toys (Montoya, NM)')
# (583, 'Wingtip Toys (Knights Landing, CA)')
# (584, 'Wingtip Toys (Cache, OK)')
# (585, 'Wingtip Toys (Towaco, NJ)')
# (586, 'Wingtip Toys (Lynne, FL)')
# (587, 'Wingtip Toys (Plata, TX)')
# (588, 'Wingtip Toys (Oak Point, TX)')
# (589, 'Wingtip Toys (Alcester, SD)')
# (590, 'Wingtip Toys (McAdenville, NC)')
# (591, 'Wingtip Toys (Idaho City, ID)')
# (592, 'Wingtip Toys (Dunkerton, IA)')
# (593, 'Wingtip Toys (Cuyamungue, NM)')
# (594, 'Wingtip Toys (Marfa, TX)')
# (595, 'Wingtip Toys (Accomac, VA)')
# (596, 'Wingtip Toys (Cos Cob, CT)')
# (597, 'Wingtip Toys (Haycock, AK)')
# (598, "Wingtip Toys (Kapa'a, HI)")
# (599, 'Wingtip Toys (Dickworsham, TX)')
# (600, 'Wingtip Toys (Caro, MI)')
# (601, 'Wingtip Toys (Ruthsburg, MD)')
# (801, 'Eric Torres')
# (802, 'Cosmina Vlad')
# (803, 'Bala Dixit')
# (804, 'Aleksandrs Riekstins')
# (805, 'Ratan Poddar')
# (806, 'Shi Tu')
# (807, 'Gunnar Lohmus')
# (808, 'Jackson Kolios')
# (809, 'Madhu Dwivedi')
# (810, 'Alena Kellnerova')
# (811, 'Surendra Sahu')
# (812, 'Celica Barajas')
# (813, 'Shyam Poddar')
# (814, 'Johanna Hoornstra')
# (815, 'Libuse Valentova')
# (816, 'Harsha Huq')
# (817, 'Agrita Kanepa')
# (818, 'Liia Orav')
# (819, 'Santiago Vera')
# (820, 'Knut Svensson')
# (821, 'Kwanjai Saowaluk')
# (822, 'Suparna Bhattacharya')
# (823, 'Francisca Laureano')
# (824, 'Risto Valbe')
# (825, 'Jayanta Thakur')
# (826, 'Leila Carvalho')
# (827, 'Crina Grasu')
# (828, 'Sercan Celik')
# (829, 'Jack Walker')
# (830, 'Jana Fialova')
# (831, 'Bhaavan Rai')
# (832, 'Aakriti Byrraju')
# (833, 'Devraj Rao')
# (834, 'Cong Hoa')
# (835, 'Dominic Davignon')
# (836, 'Abel Spirlea')
# (837, 'Anil Sarkar')
# (838, 'Pavel Bogdanov')
# (839, 'Juan Morse')
# (840, 'Rodrigo Figueiredo')
# (841, 'Camille Authier')
# (842, 'Biju Deb')
# (843, 'Marija Justina Pasek')
# (844, 'Durdanah Abbasi')
# (845, 'Emilie Hrdlickova')
# (846, 'Malorie Bousquet')
# (847, 'Kristiina Ivanov')
# (848, 'Alvin Bollinger')
# (849, 'Sabine Zalite')
# (850, 'Daakshaayaani Sankaramanchi')
# (851, 'Ebru Erdogan')
# (852, 'Bhagavaan Atluri')
# (853, 'Caterina Pinto')
# (854, 'Daakshaayaani Kommineni')
# (855, 'Anna Mazzanti')
# (856, 'Satish Mittal')
# (857, 'Clarissa Manfrin')
# (858, 'Bimla PrabhupÄ\x81da')
# (859, 'Shah Alizadeh')
# (860, 'Marcela Lucescu')
# (861, 'Amarasimha Vinjamuri')
# (862, 'Lana Goransson')
# (863, 'Jakub Lukes')
# (864, 'Mikhail Degtyarev')
# (865, 'Bijoya Thakur')
# (866, 'Jay Bhuiyan')
# (867, 'Jasna Cerkez')
# (868, 'Laura Sykorova')
# (869, 'Abel Tatarescu')
# (870, 'In-Su Bae')
# (871, 'Darshana Madhunapantula')
# (872, 'Katerina Hadrabova')
# (873, 'Hana Hlouskova')
# (874, 'Daniel Martensson')
# (875, 'Philip Walker')
# (876, 'Marie LeBatelier')
# (877, 'Leyla Siavashi')
# (878, 'Miriam House')
# (879, 'Jitka Necesana')
# (880, 'Edmee Glissen')
# (881, 'Magdalena Michnova')
# (882, 'Maryann Huddleston')
# (883, 'Radha Barua')
# (884, 'Anindya Ghatak')
# (885, 'Chandrashekhar Dasgupta')
# (886, 'Debbie Molina')
# (887, 'Baran Jonsson')
# (888, 'Jai Lamble')
# (889, 'Sointu Savonheimo')
# (890, 'Olya Izmaylov')
# (891, 'Taneli Riutta')
# (892, 'Bahaar Asef zade')
# (893, 'Leyla Asef zade')
# (894, 'Gabriela Hernandes')
# (895, 'Geza Roman')
# (896, 'Leonardo Folliero')
# (897, 'Allan Mannik')
# (898, 'Gopalgobinda Sikdar')
# (899, 'Chin-Sun Chang')
# (900, 'Lilli Sokk')
# (901, 'Adrian Andreasson')
# (902, 'Kamila Michnova')
# (903, 'Bing Han')
# (904, 'Olafs Rozitis')
# (905, 'Sara Huiting')
# (906, 'Ajitaab Pakalapati')
# (907, 'Eugen Agafitei')
# (908, 'Sumati Bhat')
# (909, 'Dena Glissen')
# (910, 'Elina Kaleja')
# (911, 'Liidia Lepp')
# (912, 'Volkan senturk')
# (913, 'Violetta KlanCisar')
# (914, 'Chandana Shasthri')
# (915, 'Ana Florea')
# (916, 'Pinja Jantunen')
# (917, 'Pari Hosseini')
# (918, 'Isidora Morales')
# (919, 'Kertu Sokk')
# (920, 'Gayatri Gajula')
# (921, 'Victoria Lacusta')
# (922, 'Sumati Chatterjee')
# (923, 'Tai Bach')
# (924, 'Eva Schulteisz')
# (925, 'Can ozcan')
# (926, 'Richard Friar')
# (927, 'Matyas Sedlar')
# (928, 'Arijit Bhuiyan')
# (929, 'Vladimir Henzl')
# (930, 'Shantanu Huq')
# (931, 'Nada Jovanovic')
# (932, 'Nicolo Cattaneo')
# (933, 'Joel Carrillo')
# (934, 'Ivan Sepulveda')
# (935, 'Daevasree Samavedam')
# (936, 'Ludmila Smidova')
# (937, 'Manca Hrastovsek')
# (938, 'Anna Gyarmathi')
# (939, 'Ioana Florea')
# (940, 'Lorin Astrom')
# (941, 'Bishwa Chatterjee')
# (942, 'Chaayaadaevi Sonti')
# (943, 'Drazenka Jelic')
# (944, 'Ida Celma')
# (945, 'Hoc Tran')
# (946, 'David safranek')
# (947, 'Svetlana Todorovic')
# (948, 'Richard Zahradnicek')
# (949, 'Seo-yun Paik')
# (950, 'Emily Whittle')
# (951, 'Eliza Persson')
# (952, 'Chuan Wattanasin')
# (953, 'Linh Dao')
# (954, 'Nasrin Omidzadeh')
# (955, 'Raghu Sandhu')
# (956, 'Nhung Thach')
# (957, 'Hee-Young Suh')
# (958, 'Valentin Tirlea')
# (959, 'Dhaatri Chavva')
# (960, 'Edgar Jogi')
# (961, 'Rani Ganguly')
# (962, 'Bhagavati Vinjamuri')
# (963, 'Be Trang')
# (964, 'Ingrida Zeltina')
# (965, 'Phoung Cu')
# (966, 'Sara Walkky')
# (967, 'Meera Patel')
# (968, 'Anca Gogean')
# (969, 'Staffan Persson')
# (970, 'Isidora Urias')
# (971, 'Dhanishta Mokkapati')
# (972, 'Lakshmi Benipal')
# (973, 'Kumar Kamei')
# (974, 'Emil Roman')
# (975, 'Prabodh Nair')
# (976, 'Alinne Matos')
# (977, 'Mauno Laurila')
# (978, 'Baalaamjali Devulapalli')
# (979, 'Melani Ravlen')
# (980, 'Om Yadav')
# (981, 'Mahmut ozbek')
# (982, 'Yves Belisle')
# (983, 'Sabine Alksne')
# (984, 'Kamala Nishad')
# (985, 'Roko Ilic')
# (986, 'Neil Farrelly')
# (987, 'Akhil Nadar')
# (988, 'Maksims Krastins')
# (989, 'Milinka Zujovic')
# (990, 'Andris Saulitis')
# (991, 'Valter Viiding')
# (992, 'Amarakumaar Gadiyaram')
# (993, 'Gasper Havzija')
# (994, 'Libuse Kuchtova')
# (995, 'Kumar Naicker')
# (996, 'Laszlo Gardenier')
# (997, 'Nada Ana Slosar')
# (998, 'Mahavir Sonkar')
# (999, 'Kristi Part')
# (1000, 'Krishnam Allu')
# (1001, 'Dinh Mai')
# (1002, 'Stefan Selezeanu')
# (1003, 'Hue Ton')
# (1004, 'Drishti Bose')
# (1005, 'Bhadram Kamasamudram')
# (1006, 'Taj Syme')
# (1007, 'Irma Berzina')
# (1008, 'Vedrana Kovacevic')
# (1009, 'Bhagavateeprasaad Malladi')
# (1010, 'Serdar ozCelik')
# (1011, 'Rajeev Sandhu')
# (1012, 'Urve Kasesalu')
# (1013, 'Annette  Hetu')
# (1014, 'Narendra Tickoo')
# (1015, 'Isa Hulsegge')
# (1016, 'Aive Petrov')
# (1017, 'David Novacek ')
# (1018, 'Nils Kaulins')
# (1019, 'Dhanishta Pullela')
# (1020, 'Hai Banh')
# (1021, 'Fabrice Cloutier')
# (1022, 'Nadir Seddigh')
# (1023, 'Farzana Habibi')
# (1024, 'Arka Chatterjee')
# (1025, 'Tuulikki Linna')
# (1026, 'Daniella Cavalcante')
# (1027, 'Serdar ozden')
# (1028, 'Emma Van Zant')
# (1029, 'Veronika Necesana')
# (1030, 'Chompoo Atitarn')
# (1031, 'Dipti Shah')
# (1032, 'Som Mukherjee')
# (1033, 'Cuneyt Arslan')
# (1034, 'Aishwarya Dantuluri')
# (1035, 'Manjunatha Karnik')
# (1036, 'Erik Malk')
# (1037, 'David Jaramillo')
# (1038, 'Damodara Trivedi')
# (1039, 'Bhaamini Palagummi')
# (1040, 'Damodar Shenoy')
# (1041, 'Tomo Vidovic')
# (1042, 'Nguyen Banh')
# (1043, 'Raj Verma')
# (1044, 'Hanita Nookala')
# (1045, 'Matteo Cattaneo')
# (1046, 'Christian Couet')
# (1047, 'Ivana Hadrabova')
# (1048, 'Abhra Ganguly')
# (1049, 'Amet Shergill')
# (1050, 'Amrita Ganguly')
# (1051, 'Sylvie Laramee')
# (1052, 'Ian Olofsson')
# (1053, 'Luis Saucedo')
# (1054, 'Emma Salpa')
# (1055, 'Adriana Pena')
# (1056, 'Kalyani Benjaree')
# (1057, 'Ganesh Majumdar')
# (1058, 'Jaroslav Fisar')
# (1059, 'Jibek Juniskyzy')
# (1060, 'Anand Mudaliyar')
# (1061, 'Agrita Abele')
